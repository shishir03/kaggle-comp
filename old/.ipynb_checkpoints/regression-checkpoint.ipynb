# %% [markdown]
# # W2 Discussion

# %% [markdown]
# ## Linear Regression in PyTorch:
#
# Recall that for Linear Regression:
#
# - Training Data: $S = \{x_i,y_i\}_{i=1}^N$
# - Model Class: $f(x|w,b) = w^Tx - b$
# - Loss Function: $L(a,b) = (a-b)^2$

# %%
import torch, numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import torch.nn as nn
import torch.optim as optim
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
print(f"PyTorch Version: {torch.__version__}")
# Out:
# PyTorch Version: 2.0.0+cu117

# %% [markdown]
# # Load the data
#
# We will load the data with pandas

# %%
# Load the dataset
train_df = pd.read_csv('../archive/train.csv')
test_df = pd.read_csv('../archive/test_public.csv')

# %% [markdown]
# # Encode the Data
#
# Convert all categorical data to numerical values and do some preprocessing on the data

# %%
encoder = LabelEncoder()
train_df['CALL_TYPE'] = encoder.fit_transform(train_df['CALL_TYPE'])
train_df['DAY_TYPE'] = encoder.fit_transform(train_df['DAY_TYPE'])

# Split the data into features and target
features = train_df.drop(['TRIP_ID', 'MISSING_DATA', 'POLYLINE'], axis=1)#.head(1000)
# target = train_df['POLYLINE'].head(1000).str.count(',') * 15
target = train_df['POLYLINE'].str.count(',') * 15

features.iloc[:, 3] -= 20000000
features.iloc[:, 4] /= 100000000

# %% [markdown]
# ## Convert the data into tensors
#
# We start by splitting our data into test and target datasets. We then replace all NaN values with 0, convert the datasets to tensors, and split the tensors into batches size 1000

# %%
X_train, X_val, y_train, y_val = train_test_split(features, target, test_size=0.2, random_state=42)

# Check for NaN values and replace with zeros
X_train[X_train != X_train] = 0
X_val[X_val != X_val] = 0

X_train = torch.tensor(X_train.values, dtype=torch.float32)
X_val = torch.tensor(X_val.values, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32)
y_val = torch.tensor(y_val.values, dtype=torch.float32)
y_train = torch.unsqueeze(y_train, 1)
y_val = torch.unsqueeze(y_val, 1)

X_train_batches = torch.split(X_train, 1000)
X_val_batches = torch.split(X_val, 1000)
y_train_batches = torch.split(y_train, 1000)
y_val_batches = torch.split(y_val, 1000)
#X_train = X_train[0:1000]
#y_train = y_train[0:1000]

print(X_train.shape)
# Out:
# torch.Size([1368536, 6])

# %% [markdown]
# # PyTorch Linear Regression
#
# Let us construct a very simple neural network with 1 linear layer (2 parameters, 1 weight and 1 bias) and train it using:
# - Training Data: $S = {x_i,y_i}_{i=1}^N$
# - Model Class: $f(x|w,b) = w^Tx - b$
# - Loss Function: $L(a,b) = (a-b)^2$
#
# Note: There is an analytical solution to the Least-Squares Linear Regression problem using the pseudo-inverse. We are using gradient descent to solve it just as an example.

# %%
# Define Model
class LinearRegression(nn.Module):
  def __init__(self, input_dim, output_dim):
    super(LinearRegression, self).__init__()
    self.layer = torch.nn.Sequential(
      torch.nn.Linear(input_dim, output_dim),
    )

  def forward(self, x):
    out = self.layer(x)
    return out

# %%
model = LinearRegression(6, 1)
# Define Loss Function / Objective Function
loss_fn = torch.nn.MSELoss()

# Define optimizer (this will perform your parameter updates use)
lr = 0.05
opt = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)

# %% [markdown]
# ## Train the Data (this takes a very long time!)

# %%
train_err = []
test_err = []
parameters = []
for i in range(1000):
  model.train()
  # print(X_train)
  for j, x_batch in enumerate(X_train_batches):
    x = torch.nn.functional.normalize(X_train, p=2.0, dim=0)
    y_pred = model(x_batch) # Compute model outputs
    y_pred[y_pred != y_pred] = 0
    loss = loss_fn(y_pred, y_train_batches[j]) # Compute MSE
    opt.zero_grad() # Must reset the gradients every step. Otherwise, gradients from previous iterations would cause interference!!!
    loss.backward() # Compute gradients of all parameters (our model) with respect to our computed loss value (a singular value)
    nn.utils.clip_grad_norm_(model.parameters(), 0.5) # Clip gradients
    opt.step() # One gradient step
  
  print(i, loss.item())
  train_err.append(loss_fn(model(X_train), y_train))
  
  model.eval()
  with torch.no_grad():
    test_err.append(loss_fn(model(X_val[0]), y_val[0]).item())
# Out:
# 0 2782799.0
# 1 2781928.0
# 2 2765220.75
# 3 2757664.5
# 4 2742678.25
# 5 2743453.25
# 6 2728672.25
# 7 2723549.25
# 8 2710040.0
# 9 2711317.75
# 10 2697923.75
# 11 2694675.5
# 12 2682195.5
# 13 2683644.25
# 14 2671245.0
# 15 2669485.25
# 16 2657732.25
# 17 2659153.25
# 18 2647482.25
# 19 2646956.75
# 20 2635732.5
# 21 2637012.25
# 22 2625893.75
# 23 2626410.75
# 24 2615586.0
# 25 2616660.25
# 26 2605973.0
# 27 2607406.5
# 28 2596894.0
# 29 2597721.75
# 30 2587388.5
# 31 2589639.75
# 32 2579375.75
# 33 2579948.0
# 34 2569901.5
# 35 2572908.0
# 36 2562845.0
# 37 2563148.75
# 38 2553356.25
# 39 2557057.25
# 40 2547169.0
# 41 2547206.5
# 42 2537629.75
# 43 2541986.0
# 44 2532245.0
# 45 2532023.0
# 46 2522643.5
# 47 2527610.25
# 48 2518006.5
# 49 2517526.75
# 50 2508322.75
# 51 2513881.25
# 52 2504392.75
# 53 2503667.5
# 54 2494622.0
# 55 2500744.0
# 56 2491361.75
# 57 2490392.25
# 58 2481501.25
# 59 2488162.0
# 60 2478880.0
# 61 2477669.5
# 62 2468919.5
# 63 2476100.25
# 64 2466909.25
# 65 2465464.75
# 66 2456846.0
# 67 2464533.75
# 68 2455427.0
# 69 2453752.5
# 70 2445257.0
# 71 2453433.75
# 72 2444408.0
# 73 2442505.25
# 74 2434128.5
# 75 2442776.0
# 76 2433823.25
# 77 2431705.0
# 78 2423439.25
# 79 2432545.0
# 80 2423661.5
# 81 2421323.5
# 82 2413166.25
# 83 2422719.75
# 84 2413899.25
# 85 2411348.25
# 86 2403292.5
# 87 2413277.25
# 88 2404520.0
# 89 2401758.25
# 90 2393799.75
# 91 2404207.25
# 92 2395504.75
# 93 2392541.25
# 94 2384677.25
# 95 2395491.75
# 96 2386844.75
# 97 2383676.5
# 98 2375898.0
# 99 2387115.75
# 100 2378517.75
# 101 2375150.5
# 102 2367458.25
# 103 2379064.0
# 104 2370515.0
# 105 2366949.0
# 106 2359340.0
# 107 2371325.25
# 108 2362820.5
# 109 2359059.75
# 110 2351529.0
# 111 2363883.5
# 112 2355422.5
# 113 2351469.5
# 114 2344012.0
# 115 2356730.75
# 116 2348305.75
# 117 2344169.0
# 118 2336780.0
# 119 2349851.0
# 120 2341464.0
# 121 2337138.75
# 122 2329822.5
# 123 2343234.25
# 124 2334883.0
# 125 2330375.5
# 126 2323126.0
# 127 2336870.75
# 128 2328552.0
# 129 2323862.5
# 130 2316679.5
# 131 2330750.25
# 132 2322462.5
# 133 2317598.25
# 134 2310475.5
# 941 2142907.25
# 942 2137500.25
# 943 2165428.25
# 944 2157246.5
# 945 2142888.25
# 946 2137483.0
# 947 2165416.0
# 948 2157234.25
# 949 2142870.5
# 950 2137463.25
# 951 2165397.25
# 952 2157215.25
# 953 2142854.25
# 954 2137445.75
# 955 2165387.5
# 956 2157202.25
# 957 2142834.5
# 958 2137428.75
# 959 2165370.25
# 960 2157189.0
# 961 2142817.25
# 962 2137411.75
# 963 2165360.25
# 964 2157174.75
# 965 2142800.75
# 966 2137395.75
# 967 2165346.75
# 968 2157161.0
# 969 2142784.5
# 970 2137378.25
# 971 2165334.25
# 972 2157149.0
# 973 2142768.25
# 974 2137363.5
# 975 2165319.5
# 976 2157135.0
# 977 2142752.0
# 978 2137347.75
# 979 2165308.5
# 980 2157123.0
# 981 2142735.75
# 982 2137332.75
# 983 2165298.25
# 984 2157111.25
# 985 2142724.5
# 986 2137318.75
# 987 2165281.25
# 988 2157098.5
# 989 2142707.75
# 990 2137305.25
# 991 2165271.0
# 992 2157086.5
# 993 2142694.5
# 994 2137290.5
# 995 2165262.25
# 996 2157074.75
# 997 2142680.0
# 998 2137274.75
# 999 2165251.25

# %% [markdown]
# ### Display model output and final RMSE

# %%
import math

final_pred = model(X_train)
print(final_pred, math.sqrt(loss_fn(final_pred, y_train).item()))
# Out:
# tensor([[1557.0736],
#         [1421.2059],
#         [1495.0138],
#         ...,
#         [1408.2559],
#         [1401.3384],
#         [1499.8942]], grad_fn=<AddmmBackward0>) 1376.8461696936226

# %%
print(f"Final Model: {model.layer[0].weight} {model.layer[0].bias}")
# Out:
# Final Model: Parameter containing:
# tensor([[ 1.0543e+01,  1.1243e-02, -4.8859e+00,  1.1748e-01,  1.0484e+02,
#           1.6603e-01]], requires_grad=True) Parameter containing:
# tensor([7.7334], requires_grad=True)

# %%
test_df['CALL_TYPE'] = encoder.fit_transform(test_df['CALL_TYPE'])
test_df['DAY_TYPE'] = encoder.fit_transform(test_df['DAY_TYPE'])

# Split the data into features and target
features = test_df.drop(['TRIP_ID', 'MISSING_DATA'], axis=1)
features.iloc[:, 3] -= 20000000
features.iloc[:, 4] /= 100000000

features[features != features] = 0
features = torch.tensor(features.values, dtype=torch.float32)

# %%
import csv

fields = ['TRIP_ID', 'TRAVEL_TIME']
rows = []

for i in range(320):
    trip_id = test_df.iloc[i, 0]
    rows.append([trip_id, model(features[i])[0].item()])
    
with open("output.csv", 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %% [markdown]
# ## Make some fancy graphs

# %%
def visualize_graphs(train_err, test_err, title=""):
  plt.figure(figsize=(12,9))
  plt.axhline(color="red", lw=1)
  plt.axvline(color="red", lw=1)
  if title:
    plt.title(title, fontsize=24)
  plt.xlabel("Iterations", fontsize=18)
  plt.ylabel("Loss", fontsize=18)
  
  train_err = [i.item() for i in train_err]
  train_err = [math.sqrt(i) for i in train_err]
  test_err = [math.sqrt(i) for i in test_err]
  plt.plot(train_err, label="train")
  plt.plot(test_err, label="test")

  # ax = plt.gca()
  # ax.set_yscale("log")
  
  plt.ylim(0, 1800)
  plt.xlim(-10, 1000)
  
  plt.legend(loc="upper right")
  
  
visualize_graphs(train_err, test_err, "Loss plots")
